# %%
import pandas as pd
df=pd.read_csv('titanic-passengers.csv', sep=";" )
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop("Cabin", axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare Embarked
# 0        0      248740  13.0000        S
# 1        0      348123   7.6500        S
# 2        0      350050   7.8542        S
# 3        4      349909  21.0750        S
# 4        0  F.C. 12750  52.0000        S
# ..     ...         ...      ...      ...
# 886      0      237736  30.0708        C
# 887      0        2669   7.2292        C
# 888      0      315084   8.6625        S
# 889      0      349215   7.8958        S
# 890      0      250655  26.0000        S
#
# [891 rows x 11 columns]

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare Embarked
# 0        0      0      248740  13.0000        S
# 1        0      0      348123   7.6500        S
# 2        0      0      350050   7.8542        S
# 3        0      4      349909  21.0750        S
# 4        1      0  F.C. 12750  52.0000        S
# ..     ...    ...         ...      ...      ...
# 886      1      0      237736  30.0708        C
# 887      0      0        2669   7.2292        C
# 888      0      0      315084   8.6625        S
# 889      0      0      349215   7.8958        S
# 890      0      0      250655  26.0000        S
#
# [891 rows x 11 columns]

# %%
df.drop("Embarked", axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare
# 0        0      0      248740  13.0000
# 1        0      0      348123   7.6500
# 2        0      0      350050   7.8542
# 3        0      4      349909  21.0750
# 4        1      0  F.C. 12750  52.0000
# ..     ...    ...         ...      ...
# 886      1      0      237736  30.0708
# 887      0      0        2669   7.2292
# 888      0      0      315084   8.6625
# 889      0      0      349215   7.8958
# 890      0      0      250655  26.0000
#
# [891 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
plt.title("Histogram of different ages")
plt.xlabel("Age")
df['Age'].plot.hist()

# %%
import matplotlib.pyplot as plt
plt.title("Pclass")
plt.xlabel("the class")
df['Pclass'].plot.hist()

# %%
import matplotlib.pyplot as plt
plt.xlabel("Survived or not")
plt.ylabel("how many")
plt.title("survived")
vc=df['Survived'].value_counts()
vc.plot.bar(rot=45)

# %%
import matplotlib.pyplot as plt
plt.xlabel("male or female")
plt.ylabel("frecency")
plt.title("sex")
vc=df['Sex'].value_counts()
vc.plot.bar(rot=45)

# %%
import seaborn as sns
g = sns.FacetGrid(df, col="Sex", row="Survived", margin_titles=True)
g.map(plt.hist, "Age",color="purple");

# %%
import seaborn as sns
g = sns.FacetGrid(df, col="Pclass", row="Survived", margin_titles=True)
g.map(plt.hist, "Fare",color="purple");

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map( df )

# %%
df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-40-4f213bff2c00> in <module>
# ----> 1 df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1223         """
#    1224         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
# -> 1225         return self._cython_agg_general(
#    1226             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1227         )
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     991         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#     992     ) -> DataFrame:
# --> 993         agg_blocks, agg_items = self._cython_agg_blocks(
#     994             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     995         )
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1093
#    1094         if not (agg_blocks or split_frames):
# -> 1095             raise DataError("No numeric types to aggregate")
#    1096
#    1097         if split_items:
#
# DataError: No numeric types to aggregate

# %%
cleanup_nums={
    "Survived":{"No":0, "Yes":1}
}
df.replace(cleanup_nums, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare
# 0        0      0      248740  13.0000
# 1        0      0      348123   7.6500
# 2        0      0      350050   7.8542
# 3        0      4      349909  21.0750
# 4        1      0  F.C. 12750  52.0000
# ..     ...    ...         ...      ...
# 886      1      0      237736  30.0708
# 887      0      0        2669   7.2292
# 888      0      0      315084   8.6625
# 889      0      0      349215   7.8958
# 890      0      0      250655  26.0000
#
# [891 rows x 10 columns]

# %%
df.drop("Ticket",axis=1, inplace=True)
df['Title'] = df.Name.apply(lambda name: name.split(',')[1] .split('.')[0].strip())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch     Fare Title
# 0        0      0  13.0000    Mr
# 1        0      0   7.6500    Mr
# 2        0      0   7.8542    Mr
# 3        0      4  21.0750   Mrs
# 4        1      0  52.0000    Mr
# ..     ...    ...      ...   ...
# 886      1      0  30.0708   Mrs
# 887      0      0   7.2292    Mr
# 888      0      0   8.6625  Miss
# 889      0      0   7.8958    Mr
# 890      0      0  26.0000  Miss
#
# [891 rows x 10 columns]

# %%
g = sns.FacetGrid(df, col="Title")
g.map(plt.hist, "Age",color="purple")

# %%
g = sns.FacetGrid(df, col="Title")
g.map(plt.hist, "Sex",color="purple")

# %%
g = sns.FacetGrid(df, col="Title")
g.map(plt.hist, "Fare",color="purple")

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master", 

                    }
df.Title = df.Title.map(Title_Dictionary)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch     Fare Title
# 0        0      0  13.0000   Mrs
# 1        0      0   7.6500   Mrs
# 2        0      0   7.8542   Mrs
# 3        0      4  21.0750   Mrs
# 4        1      0  52.0000   Mrs
# ..     ...    ...      ...   ...
# 886      1      0  30.0708   Mrs
# 887      0      0   7.2292   Mrs
# 888      0      0   8.6625  Miss
# 889      0      0   7.8958   Mrs
# 890      0      0  26.0000  Miss
#
# [891 rows x 10 columns]

# %%
g = sns.FacetGrid(df, col="Title")
g.map(plt.hist, "Fare",color="purple")

# %%
g = sns.FacetGrid(df, col="Title")
g.map(plt.hist, "Sex",color="purple")

# %%
g = sns.FacetGrid(df, col="Title")
g.map(plt.hist, "Age",color="purple")

# %%
df["Familysize"] = df.Parch + df.SibSp + 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch     Fare Title  Familysize
# 0        0      0  13.0000   Mrs           1
# 1        0      0   7.6500   Mrs           1
# 2        0      0   7.8542   Mrs           1
# 3        0      4  21.0750   Mrs           5
# 4        1      0  52.0000   Mrs           2
# ..     ...    ...      ...   ...         ...
# 886      1      0  30.0708   Mrs           2
# 887      0      0   7.2292   Mrs           1
# 888      0      0   8.6625  Miss           1
# 889      0      0   7.8958   Mrs           1
# 890      0      0  26.0000  Miss           1
#
# [891 rows x 11 columns]

# %%
NO,f this feature is  not useful
# Out:
#   File "<ipython-input-59-a8f9bf1803a8>", line 1
#     NO,f this feature is  not useful
#          ^
# SyntaxError: invalid syntax
