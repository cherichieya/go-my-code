# %%
import pandas as pd
df=pd.read_csv('titanic-passengers.csv', sep=";" )
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data=new_data.drop(["Cabin"],axis=1)
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
data=preprocess_data(df)
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
x=data.drop(["Survived", "Name", "Ticket", "Embarked"], axis=1)
y= data["Survived"]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

dtree = tree.DecisionTreeClassifier()  
dtree.fit(x_train, y_train)  
y_pred=dtree.predict(x_test) 
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.776536312849162

# %%
from sklearn.tree import plot_tree
def plot_decision_tree(tr):
    global x,y
    plt.figure(figsize= (30,20))
    plot_tree(tr, filled= True,feature_names = x.columns, proportion = True)

# %%
plot_decision_tree(dtree)

# %%
dtree = tree.DecisionTreeClassifier(max_depth=4)  
dtree.fit(x_train, y_train)  
y_pred=dtree.predict(x_test) 
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
plot_decision_tree(dtree)

# %%
dtree = tree.DecisionTreeClassifier(max_depth= 6,criterion="gini", splitter="random",max_leaf_nodes= 10,min_samples_leaf= 6)  
dtree.fit(x_train, y_train)  
y_pred=dtree.predict(x_test) 
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics

# %%
clf=RandomForestClassifier(n_estimators=10) 
clf.fit(x_train, y_train) 
y_pred=clf.predict(x_test) 
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8435754189944135

# %%
clf=RandomForestClassifier(n_estimators=100) 
clf.fit(x_train, y_train) 
y_pred=clf.predict(x_test) 
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8603351955307262
